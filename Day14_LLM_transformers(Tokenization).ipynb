# %% [markdown]
# <a href="https://colab.research.google.com/github/Vivekshrotriya1/Capgemini-Training/blob/main/Day14_LLM_transformers(Tokenization).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text Generation
# #  Scenario:
#  AI‑Powered Email Assistant
#  You’re building an email drafting assistant for a corporate team.
#   When a user starts typing:
# “Artificial Intelligence will…”
#  The assistant uses GPT‑2 to auto‑complete the sentence with a coherent continuation.
#  Example output:
#  “Artificial Intelligence will transform the way businesses interact with customers,
# enabling faster decisions and personalized experiences.”

# %%
from transformers import pipeline

generator = pipeline('text-generation', model='gpt2')
print(generator("Artificial Intellegence will",max_length=30))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Artificial Intellegence will be a huge hit with the gaming market. For many, the idea of AI being an extension of human intelligence, especially in the gaming industry, is quite intriguing. For this reason, it was decided that the hardware used for the AI and AI-based systems would be the same as the hardware used for the human brain.\n\nThe new "AI-based systems" are designed to perform more complex tasks than humans, such as reading and writing. They can do much more than read human memory and write to a machine code, but they are not designed to be as powerful as machine code. This means that they are not built to perform what humans can do.\n\nThe AI-based systems will work around the fact that there is a huge amount of processing power available to a system, and that there is a large amount of processing power available to an operating system. This means that the processing power of the systems will be much lower than that of the human brain.\n\nThe new AI-based systems will be able to do some additional things to their computing power. For example, they will be able to write to a machine code when the computer thinks about something. This will improve the performance of the systems. In the future, the AI-based systems will'}]

# %% [markdown]
# #  Scenario: Game Storyline Generator
#  You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
#  The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
#  The GPT‑2 pipeline continues the story:
#  “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#   a cursed artifact buried beneath the old ruins.”

# %%
from transformers import pipeline

generator = pipeline('text-generation', model='gpt2')
print(generator("The hero enters the ancient forest and discovers a hidden village where the people whisper of a cursed artifact buried beneath the old ruins.",max_length=30))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The hero enters the ancient forest and discovers a hidden village where the people whisper of a cursed artifact buried beneath the old ruins. The story follows the young hero, Lillius, who meets the villagers, and he is introduced to a mysterious woman named Vella, who is the daughter of a noblewoman who lives in the village.\n\nThe story follows the young hero, Lillius, who meets the villagers, and he is introduced to a strange woman named Vella, who is the daughter of a noblewoman who lives in the village.\n\nThe story follows the young hero, Lillius, who meets the villagers, and he is introduced to a mysterious woman named Vella, who is the daughter of a noblewoman who lives in the village.\n\nThe stories follow the young hero, Lillius, who meets the villagers, and he is introduced to a strange woman named Vella, who is the daughter of a noblewoman who lives in the village.\n\nThe story follows the young hero, Lillius, who meets the villagers, and he is introduced to a strange woman named Vella, who is the daughter of a noblewoman who lives in the village.\n\nThe story follows the young hero, Lillius, who meets the villagers, and he is introduced to a strange woman named Vella, who is the daughter of a noblewoman'}]

# %% [markdown]
# # Tokenization
#
# # Scenario:
#  Research Assistant for Academic Papers
# Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
# A researcher uploads a sentence:
# “Deep learning models are powerful”
#  Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Deep learning models are powerful"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ['deep', 'learning', 'models', 'are', 'powerful']

# %% [markdown]
# # 🏥 Scenario: Healthcare Chatbot for Patient Queries
# A hospital is developing a chatbot to help patients ask questions about their health.
#  A patient types:
# “Deep learning models are powerful” (or in practice, something like “I have chest pain and shortness of breath”).
#  The chatbot uses the BERT tokenizer to break the sentence into tokens:

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "I have chest pain and shortness of breath"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# ['i', 'have', 'chest', 'pain', 'and', 'short', '##ness', 'of', 'breath']

# %% [markdown]
# # Scenario: Exploring Creativity in AI Writing
# A university professor is running a workshop on creative writing with AI.
# The professor gives students the prompt:
#  “The future of Artificial Intelligence”
#  The system uses GPT‑2 to generate continuations of the sentence.
#  To demonstrate how temperature affects creativity:
#  With temperature = 0.2 (low randomness), the output is more predictable and conservative, e.g.:
#  “The future of Artificial Intelligence will bring advancements in healthcare, education, and business.”

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = "The future of Artificial Intelligence"

print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'temperature', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is in the hands of the next generation of AI researchers.\n\nThe next generation of AI researchers will be able to create artificial intelligence that will be able to solve complex problems, such as human-to-human communication, and will be able to predict the future of human-to-human communication.\n\nThe next generation of AI researchers will be able to create artificial intelligence that will be able to solve complex problems, such as human-to-human communication, and will be able to predict the future of human-to-human communication.\n\nThe next generation of AI researchers will be able to create artificial intelligence that will be able to solve complex problems, such as human-to-human communication, and will be able to predict the future of human-to-human communication.\n\nThe next generation of AI researchers will be able to create artificial intelligence that will be able to solve complex problems, such as human-to-human communication, and will be able to predict the future of human-to-human communication.\n\nThe next generation of AI researchers will be able to create artificial intelligence that will be able to solve complex problems, such as human-to-human communication, and will be able to predict the future of human-to-human communication'}]
# [{'generated_text': 'The future of Artificial Intelligence is now in question. In order to continue to advance technology, we need a more integrated, self-driving, self-driving vehicle system, not the old, self-piloted vehicles.\n\nWhat is the future of artificial intelligence?\n\nAutonomous devices were initially proposed as a solution to the problem of speeding up human activities. By now, computers are not able to solve the problem of speeding up physical activities. The problem of speeding up physical activities has been solved and we are now able to do it in a way that allows us to do it in a way that is more efficient.\n\nIn order to get more efficient at speeding up activities, automated vehicles will need to be able to be autonomous, so they are not as well-prepared for the task of driving, as they are for driving in situations of conflict. This will change in the near future.\n\nThe biggest concern about autonomous vehicles is the lack of self-driving capacity. This is the main reason why AI is being developed with so much urgency – to avoid situations where a human can cause a disturbance in a car.\n\nIn the future, however, there will be more and more autonomous vehicles that are able to drive in different situations and take on the autonomous capabilities of'}]

# %% [markdown]
# # Scenario: AI‑Powered News Headline Generator
# A digital media company wants to help journalists brainstorm headlines and opening lines for articles.
#  The system asks the journalist to enter a prompt (e.g., “Enter a prompt: The future of Artificial Intelligence”).
#  The GPT‑2 model then generates a continuation of the text, up to 50 tokens.
#  Example output:
#  “The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge
#  our understanding of human potential.”

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = input("Enter a prompt: ")

output = generator(prompt, max_length=50)

print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge our understanding of human potential.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge our understanding of human potential.
#
# The Future of Artificial Intelligence Will Shackle Our Ideas About Creativity
#
# By Brian B.
#
# Brief Summary: Artificial Intelligence is not a new technology. Some call it "computer vision," for example. But many of the most important changes in the last few decades have been in the way we think about the future and the use of artificial intelligence.
#
# Many of the major questions in our digital lives have been around how to deal with the new information we are seeing and how to deal with the new information we are learning. In a world of cloud computing, it's critical to think about how we interact with the data we are accumulating.
#
# But this kind of thinking is actually not new. The idea started in the 1980s with Google. Today, companies like Facebook, Yahoo, Microsoft, and other tech companies are creating apps that make it easy to keep your information in a safe environment.
#
# The question is: "How do we make this better?"
#
# That's the core challenge of artificial intelligence, and it's not new.
#
# The early pioneers of artificial intelligence believed that there was a need for a more self-contained, self-contained world. This idea was based on data, and eventually it became the basis for

# %% [markdown]
# # 🎓 Scenario: Student Brainstorming Tool for Essay Writing
#  A college student is struggling to start their essay.
#  The system prompts them:
#  “Enter a prompt:”
#  The student types:
#  “The impact of technology on education”
#  The GPT‑2 model generates a continuation up to 50 tokens, for example:
#  “The impact of technology on education has transformed classrooms, enabling online learning,
#  personalized study plans, and global collaboration among students.”

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = input("Enter a prompt: ")

output = generator(prompt, max_length=50)

print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: The impact of Ai in Tech Industry
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The impact of Ai in Tech Industry
#
# In 2011, the US Department of Commerce estimated that the US market for computer and networking equipment was $15 trillion while Intel alone had $16 trillion.
#
# Intel has been a big player in the US market for more than 40 years. In fact, Intel has become one of the most important players in the computer and networking industry.
#
# Intel has done a lot of development and development of its products in the US, including its own virtualization technology called "Intel Virtualization Technology".
#
# We have seen many more years of Intel's innovation in the technology and the technology to make IT more efficient and more secure. Intel has helped to create a platform for the rapid innovation and development of the Internet of Things (IoT), with a focus on software and cloud computing.
#
# Intel is a major player in the software and networking market with its Windows Server 2016 platform.
#
# Intel's role as a leading company in the IT sector
#
# Intel has been a leading player in the IT industry since 1989.
#
# Intel has always been a business leader in the IT sector.
#
# Intel has always been a leading player in the tech industry.
#
# Intel has always been a leading company in the tech industry.
#
# Intel has always been a

# %% [markdown]
# # Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
#  “Artificial Intelligence will transform”
#  - The system generates two outputs:
#  - GPT‑2 Output
#  Longer, more detailed continuation, e.g.:
#  “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
#  reshaping how humans interact with technology.”
#  → Richer but slower to run.
#  - DistilGPT‑2 Output

# %%
from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': "Artificial Intelligence will transform the way we view ourselves. We may even see a computer that works better at predicting what people would be like.\n\nThe results are stunning. In fact, the scientists reported their findings in the same issue of the journal IEEE Spectrum, which was run by the University of Chicago.\n\nTheir team uses artificial intelligence to predict people's behavior and the human mind as well as to predict what they would want to do with their lives and hobbies.\n\nThey found that people who are more socially conscious and have more money, desire to have sex, and are more likely to be interested in social interactions with others are more likely to use artificial intelligence.\n\nThey compared their results with humans and found that people were more likely to use artificial intelligence and that they were more likely to be interested in other people.\n\nThe researchers believe this could be the basis of the future of human psychology.\n\nMore information: http://www.sciencemag.org/content/38/6/739.full.pdf"}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform the way people interact with the world of our world, as it sees it, and it will transform the way people interact with the world of our world.\n\n\n\nIn other words, even the most powerful AI will take on a wide array of different kinds of roles, and be given tremendous amounts of power. Think of it as a team of AI experts, and the most powerful AI will take on a wide array of different kinds of roles, and be given tremendous amounts of power. Think of it as a team of AI experts, and the most powerful AI will take on a wide array of different kinds of roles, and be given tremendous amounts of power. Think of it as a team of AI experts, and the most powerful AI will take on a wide array of different kinds of roles, and be given tremendous amounts of power. Think of it as a team of AI experts, and the most powerful AI will take on a wide array of different types of roles, and be given tremendous amounts of power.\nThe best thing about artificial intelligence is that what it does is become a much more accurate and more powerful AI.\nNow imagine that artificial intelligence is a very powerful AI. It has been around for a long time.\nSo why do we need to think'}]

# %% [markdown]
# # Scenario: Educational Tool for Classroom Learning
#  A high school teacher is introducing students to AI‑powered writing assistants.
#  - The teacher wants to show how different models produce different styles of text.
#  - They use the same prompt:
#  “Artificial Intelligence will transform”
#  - The system generates two outputs:
#  - GPT‑2 Output
#  More elaborate continuation, e.g.:
#  “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
#  → Great for showing students how AI can generate rich, detailed ideas.
#  - DistilGPT‑2 Output
#  Shorter, faster continuation, e.g.:
#  “Artificial Intelligence will transform our daily lives.”
#  → Useful for demonstrating concise summaries.

# %%
from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Will AI take over all jobs"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': 'Will AI take over all jobs in the world?"\n\n"I don\'t know. We\'ll take over the jobs in the world. But they\'ll never take over the jobs in the world. And they won\'t do it because you didn\'t win. But they\'re going to take over the jobs in the world. And you won\'t do it. So they\'re going to make sure they have a job at all. And that is a huge problem."\n\nHe has not even begun to explore the possibility of the AI-based robots coming to American jobs.\n\n"I\'m not going to go into that. I don\'t know how long I will. But I would like to see it. I think it would be a great idea. And it\'s very interesting to see what happens, especially with the way automation is going to be used in this country."\n\nOne of the main problems with his proposal for artificial intelligence is that it will take too long for the technology to be deployed in a large number of jobs.\n\n"I have had conversations with a number of different people, and it seems that there is a lot of speculation and I think that there\'s got to be a lot of discussion about it," said Mr. Sanders (D-VT).\n\nBut'}]
# DistilGPT2: [{'generated_text': 'Will AI take over all jobs, but the government has not taken over all jobs.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}]

# %% [markdown]
# # NED(Named Entity Recognition)
# #Scenario: Sports Event Analysis
#
# Context:
#
# You are part of a sports analytics team working for a global media company. Your manager has asked you to analyze match reports and press releases to identify key entities such as teams, players, locations, dates, and numbers. This information will help the company build automated summaries and highlight reels for fans.
#
# Task:
#
# You receive the following match report excerpt:
#
# "Manchester United defeated Real Madrid 3-2 at Wembley Stadium, London. Cristiano Ronaldo scored twice, while Marcus Rashford netted the winning goal in July 2024"
#
# Your job is to run Named Entity Recognition (NER) using spacy to automatically extract structured insights.
#
# 14:44
#
# Type a message

# %%
import spacy


nlp = spacy.load("en_core_web_sm")


text = """
Manchester United defeated Real Madrid 3-2 at Wembley Stadium, London.
Cristiano Ronaldo scored twice, while Marcus Rashford netted the winning goal in July 2024.
"""

# Process the text
doc = nlp(text)

print("Match Report:\n", text)
print("\nExtracted Named Entities:\n")

# Extract entities
for ent in doc.ents:
    print(f"Entity: {ent.text}  |  Label: {ent.label_}")

print("\nStructured Insights:")

teams = []
players = []
locations = []
dates = []
numbers = []

# Categorizing entities
for ent in doc.ents:
    if ent.label_ == "ORG":
        teams.append(ent.text)
    elif ent.label_ == "PERSON":
        players.append(ent.text)
    elif ent.label_ in ["GPE", "LOC"]:
        locations.append(ent.text)
    elif ent.label_ == "DATE":
        dates.append(ent.text)
    elif ent.label_ == "CARDINAL":
        numbers.append(ent.text)

print("Teams:", teams)
print("Players:", players)
print("Locations:", locations)
print("Dates:", dates)
print("Numbers:", numbers)
# Out:
# Match Report:
#
# Manchester United defeated Real Madrid 3-2 at Wembley Stadium, London.
# Cristiano Ronaldo scored twice, while Marcus Rashford netted the winning goal in July 2024.
#
#
# Extracted Named Entities:
#
# Entity: Manchester United  |  Label: PERSON
# Entity: Wembley Stadium  |  Label: GPE
# Entity: London  |  Label: GPE
# Entity: Cristiano Ronaldo  |  Label: PERSON
# Entity: Marcus Rashford  |  Label: PERSON
# Entity: July 2024  |  Label: DATE
#
# Structured Insights:
# Teams: []
# Players: ['Manchester United', 'Cristiano Ronaldo', 'Marcus Rashford']
# Locations: ['Wembley Stadium', 'London']
# Dates: ['July 2024']
# Numbers: []

# %% [markdown]
# # Scenario-Based Assessment
# # Case Study: AI Assistant for a University Helpdesk
#
#  A large university receives thousands of student queries daily related to admissions, fees, hostel facilities, course
#   schedules, and exam results.
#
#  Currently, these queries are answered manually by staff, causing:
#
#  Slow response time
#
#  High operational cost
#
#  Inconsistent responses
#
#  The university plans to develop an AI-powered chatbot using Generative AI and Large Language Models (LLMs) to
#   automatically respond to student questions.
#
#  You are part of the AI consulting team tasked with designing the solution.
#
# # ==========================================
#  - UNIVERSITY AI HELPDESK CHATBOT
#  - Demonstrates:
#  - Generative AI
#  - Large Language Models (LLMs)
#  - Tokenization
#  - Transformer Inference
#  - Prompt Engineering
#
#
# - Install required libraries first
# - pip install transformers torch

# %%
from transformers import pipeline

# STEP 1: Load a Generative AI Model
generator = pipeline("text-generation", model="gpt2")

# STEP 2: Define University Knowledge Base
knowledge_base = """
University Helpdesk Information

Hostel Admission Requirements:
- Admission confirmation letter
- Government ID proof
- Two passport size photographs

Course Registration:
- Registration happens online through the university portal
- Students must register before the semester deadline

Fee Payment:
- Fees can be paid through the student dashboard
- Online payment methods include debit card, credit card, and net banking

Examination Schedule:
- Semester exams usually start in December and May

Library Access:
- Students must carry their university ID card
"""

# STEP 3: Function to Generate AI Response
def university_chatbot(question):

    # Prompt Engineering
    prompt = f"""
You are an AI assistant for a university helpdesk.
Use the following information to answer student questions.

{knowledge_base}

Student Question: {question}

Answer:
"""

    response = generator(
        prompt,
        max_new_tokens=120,
        num_return_sequences=1
    )

    return response[0]["generated_text"]


# STEP 4: Chatbot Interaction Loop
print("===== University AI Helpdesk Chatbot =====")
print("Type 'exit' to stop the chatbot.\n")

while True:
    user_question = input("Student Question: ")

    if user_question.lower() == "exit":
        print("Chatbot: Thank you for contacting the university helpdesk.")
        break

    answer = university_chatbot(user_question)

    print("\nChatbot Response:")
    print(answer)
    print("\n----------------------------------\n")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ===== University AI Helpdesk Chatbot =====
# Type 'exit' to stop the chatbot.
#
# Student Question: how to get a room in hostel
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=120) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Chatbot Response:
#
# You are an AI assistant for a university helpdesk.
# Use the following information to answer student questions.
#
#
# University Helpdesk Information
#
# Hostel Admission Requirements:
# - Admission confirmation letter
# - Government ID proof
# - Two passport size photographs
#
# Course Registration:
# - Registration happens online through the university portal
# - Students must register before the semester deadline
#
# Fee Payment:
# - Fees can be paid through the student dashboard
# - Online payment methods include debit card, credit card, and net banking
#
# Examination Schedule:
# - Semester exams usually start in December and May
#
# Library Access:
# - Students must carry their university ID card
#
#
# Student Question: how to get a room in hostel
#
# Answer:
#
# - Students must bring a copy of their university ID card (if available)
#
# - Students may choose to bring their own ID cards or a paper document to complete their application
#
#
# Student Question: how to get your credit card card
#
# Answer:
#
# - Students must bring their credit card to the office to complete their application
#
# - The office is located at the university
#
# - Once you get your credit card, you will have a full list of your university ID
#
# - Once you complete your application, you will have to pay your student fee
#
# - Students who
#
# ----------------------------------
#
# Student Question: exit
# Chatbot: Thank you for contacting the university helpdesk.
